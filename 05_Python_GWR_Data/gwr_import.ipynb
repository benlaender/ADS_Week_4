# %% [markdown]
# # Preparation of GWR - Data

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import json
import folium
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from datetime import date

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/ADS_Week_4/05_Python_GWR_Data

# %% [markdown]
# ## Download GWR data
#
# Source: https://public.madd.bfs.admin.ch

# %%
# Download latest file for the Canton of Zurich
url = "https://public.madd.bfs.admin.ch/buildings_ow.geojson"
response = requests.get(url)

# Ensure response is valid
if response.status_code == 200:
    # Open file in write mode and write the response content
    with open('buildings_zh.geojson', 'wb') as file:
        file.write(response.content)
else:
    print(f"Failed to download file, status code: {response.status_code}")

# %% [markdown]
# ## Import latest GWR Data

# %%
# Load json file
with open('buildings_zh.geojson') as f:
    data = json.load(f)

# Flatten nested json data
df_orig = pd.json_normalize(data, record_path=['features'])
df_orig

# Remove prefix
df_orig.columns = df_orig.columns.str.replace('properties.', '')
df_orig.columns = df_orig.columns.str.replace('geometry.', '')

# Create copy
df = df_orig.copy()
df.head()
# Out:
#       type       egid  buildingStatus  buildingCategory  buildingClass  \
# 0  Feature  101235305            1007              1020           1110
# 1  Feature  101235307            1004              1020           1110
# 2  Feature  101235308            1004              1020           1122
# 3  Feature  101235310            1004              1020           1110
# 4  Feature  101235311            1004              1020           1110
#
#    municipalityNumber municipalityName canton   type  \
# 0                1401          Alpnach     OW  Point
# 1                1401          Alpnach     OW  Point
# 2                1401          Alpnach     OW  Point
# 3                1401          Alpnach     OW  Point
# 4                1401          Alpnach     OW  Point
#
#                   coordinates
# 0          [2662391, 1198346]
# 1  [2662273.495, 1198664.438]
# 2  [2663069.775, 1200010.861]
# 3  [2662170.316, 1198226.835]
# 4  [2662135.736, 1198271.709]

# %% [markdown]
# ## Separate Swiss LV95 coordinates

# %%
# Separate coordinates
df['x_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['x_coord']
df['y_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['y_coord']

# Remove column 'coordinates'
df = df.drop(['coordinates'], axis=1)
df
# Out:
#           type       egid  buildingStatus  buildingCategory  buildingClass  \
# 0      Feature  101235305            1007              1020           1110
# 1      Feature  101235307            1004              1020           1110
# 2      Feature  101235308            1004              1020           1122
# 3      Feature  101235310            1004              1020           1110
# 4      Feature  101235311            1004              1020           1110
# ...        ...        ...             ...               ...            ...
# 21938  Feature    9082198            1004              1040              0
# 21939  Feature    9082200            1004              1060              0
# 21940  Feature    9082201            1004              1060              0
# 21941  Feature    9082202            1004              1060              0
# 21942  Feature    9082205            1004              1060              0
#
#        municipalityNumber municipalityName canton   type     x_coords  \
# 0                    1401          Alpnach     OW  Point  2662391.000
# 1                    1401          Alpnach     OW  Point  2662273.495
# 2                    1401          Alpnach     OW  Point  2663069.775
# 3                    1401          Alpnach     OW  Point  2662170.316
# 4                    1401          Alpnach     OW  Point  2662135.736
# ...                   ...              ...    ...    ...          ...
# 21938                1407           Sarnen     OW  Point  2661576.416
# 21939                1407           Sarnen     OW  Point  2661535.114
# 21940                1407           Sarnen     OW  Point  2661735.402
# 21941                1407           Sarnen     OW  Point  2661570.119
# 21942                1407           Sarnen     OW  Point  2662284.807
#
#           y_coords
# 0      1198346.000
# 1      1198664.438
# 2      1200010.861
# 3      1198226.835
# 4      1198271.709
# ...            ...
# 21938  1194345.086
# 21939  1194255.211
# 21940  1194681.900
# 21941  1194122.619
# 21942  1195193.426
#
# [21943 rows x 11 columns]

# %% [markdown]
# ## Create WGS84 coordinates

# %%
# Create geodataframe and calculate latitude and longitude
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['x_coords'], df['y_coords']), crs="EPSG:2056")

# Convert the Swiss LV95 coordinates to lat & lon
gdf = gdf.to_crs(epsg=4326)

# Get Latitude and Longitude
df['latitude'] = gdf['geometry'].y
df['longitude'] = gdf['geometry'].x

# Show data
df
# Out:
#           type       egid  buildingStatus  buildingCategory  buildingClass  \
# 0      Feature  101235305            1007              1020           1110
# 1      Feature  101235307            1004              1020           1110
# 2      Feature  101235308            1004              1020           1122
# 3      Feature  101235310            1004              1020           1110
# 4      Feature  101235311            1004              1020           1110
# ...        ...        ...             ...               ...            ...
# 21938  Feature    9082198            1004              1040              0
# 21939  Feature    9082200            1004              1060              0
# 21940  Feature    9082201            1004              1060              0
# 21941  Feature    9082202            1004              1060              0
# 21942  Feature    9082205            1004              1060              0
#
#        municipalityNumber municipalityName canton   type     x_coords  \
# 0                    1401          Alpnach     OW  Point  2662391.000
# 1                    1401          Alpnach     OW  Point  2662273.495
# 2                    1401          Alpnach     OW  Point  2663069.775
# 3                    1401          Alpnach     OW  Point  2662170.316
# 4                    1401          Alpnach     OW  Point  2662135.736
# ...                   ...              ...    ...    ...          ...
# 21938                1407           Sarnen     OW  Point  2661576.416
# 21939                1407           Sarnen     OW  Point  2661535.114
# 21940                1407           Sarnen     OW  Point  2661735.402
# 21941                1407           Sarnen     OW  Point  2661570.119
# 21942                1407           Sarnen     OW  Point  2662284.807
#
#           y_coords   latitude  longitude
# 0      1198346.000  46.933279   8.257952
# 1      1198664.438  46.936154   8.256452
# 2      1200010.861  46.948190   8.267095
# 3      1198226.835  46.932228   8.255038
# 4      1198271.709  46.932635   8.254590
# ...            ...        ...        ...
# 21938  1194345.086  46.897368   8.246714
# 21939  1194255.211  46.896563   8.246160
# 21940  1194681.900  46.900383   8.248846
# 21941  1194122.619  46.895367   8.246602
# 21942  1195193.426  46.904933   8.256126
#
# [21943 rows x 13 columns]

# %% [markdown]
# ## Plot subset of buildings

# %%
# Subset
df_sub = df.loc[df['municipalityName'] == 'Kerns'].sample(100).dropna()
df_sub

# Create the map
m = folium.Map(location=[df_sub['latitude'].mean(), df_sub['longitude'].mean()], zoom_start=15)

# Add points to the map
for idx, row in df_sub.iterrows():
    folium.Marker(location=([row['latitude'], 
                            row['longitude']]),
                  popup=row['buildingCategory']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2bc57b5310b13aea07f7f5ced764da4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2bc57b5310b13aea07f7f5ced764da4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2bc57b5310b13aea07f7f5ced764da4 = L.map(
#                 &quot;map_b2bc57b5310b13aea07f7f5ced764da4&quot;,
#                 {
#                     center: [46.89184176358154, 8.284399895782819],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe28068fd1a193ac5336c1879ab0403a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fe28068fd1a193ac5336c1879ab0403a.addTo(map_b2bc57b5310b13aea07f7f5ced764da4);
#
#
#             var marker_02ab7fae5fbcf8defa66019e7e64f8ce = L.marker(
#                 [46.89042463438656, 8.273176098539972],
#                 {}
#             ).addTo(map_b2bc57b5310b13aea07f7f5ced764da4);
#
#
#         var popup_d9abac368f1b5f492b4839919b62d04c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bca3bd824257086696cf07ca94906598 = $(`&lt;div id=&quot;html_bca3bd824257086696cf07ca94906598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1060&lt;/div&gt;`)[0];
#                 popup_d9abac368f1b5f492b4839919b62d04c.setContent(html_bca3bd824257086696cf07ca94906598);
#
#
#
#         marker_02ab7fae5fbcf8defa66019e7e64f8ce.bindPopup(popup_d9abac368f1b5f492b4839919b62d04c)
#         ;
#
#
#
#
#             var marker_1b94bd8a8cdbaede82a7494464edf24d = L.marker(
#                 [46.88817932772299, 8.267629766857969],
#                 {}
#             ).addTo(map_b2bc57b5310b13aea07f7f5ced764da4);
#
#
#         var popup_988298e1f27a434e61e1936ec2512f08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6729063dd2deecf16b1750598730b25d = $(`&lt;div id=&quot;html_6729063dd2deecf16b1750598730b25d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1060&lt;/div&gt;`)[0];
#                 popup_988298e1f27a434e61e1936ec2512f08.setContent(html_6729063dd2deecf16b1750598730b25d);
#
#
#
#         marker_1b94bd8a8cdbaede82a7494464edf24d.bindPopup(popup_988298e1f27a434e61e1936ec2512f08)
#         ;
#
#
#
#
#             var marker_f33f7d69d503a88a2dc03514efdffaef = L.marker(
#                 [46.90290907453026, 8.267215470977913],
#                 {}
#             ).addTo(map_b2bc57b5310b13aea07f7f5ced764da4);
#
#
#         var popup_41de5120619048b0411c9286a3503e2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f94e9703bf5bc3b739dec78432e2fbb8 = $(`&lt;div id=&quot;html_f94e9703bf5bc3b739dec78432e2fbb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1060&lt;/div&gt;`)[0];
#                 popup_41de5120619048b0411c9286a3503e2e.setContent(html_f94e9703bf5bc3b739dec78432e2fbb8);
#
#
#
#         marker_f33f7d69d503a88a2dc03514efdffaef.bindPopup(popup_41de5120619048b0411c9286a3503e2e)
#         ;
#
#
#
#
#             var marker_feb52501149d444245cf53cc3cfd76b3 = L.marker(
#                 [46.91295444249261, 8.2945026065651],
#                 {}
#             ).addTo(map_b2bc57b5310b13aea07f7f5ced764da4);
#
#
#         var popup_94e7770df865bad7708948d0eecfb344 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a33c73f6853634b5fc0b1ecfc9c94019 = $(`&lt;div id=&quot;html_a33c73f6853634b5fc0b1ecfc9c94019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1060&lt;/div&gt;`)[0];
#                 popup_94e7770df865bad7708948d0eecfb344.setContent(html_a33c73f6853634b5fc0b1ecfc9c94019);
#
#
#
#         marker_feb52501149d444245cf53cc3cfd76b3.bindPopup(popup_94e7770df865bad7708948d0eecfb344)
#         ;
#
#
#
#
#             var marker_da949c7cb5a9977a3520a93b000d0610 = L.marker(
#                 [46.90498428608389, 8.276012731455374],
#                 {}
#             ).addTo(map_b2bc57b5310b13aea07f7f5ced764da4);
#
#
#         var popup_467a7f1dd8e89198c3f0b7955f2b2e58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e682d00d1f3322dd31c03d5692527e15 = $(`&lt;div id=&quot;html_e682d00d1f3322dd31c03d5692527e15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_467a7f1dd8e89198c3f0b7955f2b2e58.setContent(html_e682d00d1f3322dd31c03d5692527e15);
#
#
#
#         marker_da949c7cb5a9977a3520a93b000d0610.bindPopup(popup_467a7f1dd8e89198c3f0b7955f2b2e58)
#         ;
#
#
#
#
#             var marker_7e4d2c285d4871b4db045a992205bda9 = L.marker(
#                 [46.77456559868195, 8.267645114255059],

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1021-azure
# Datetime: 2024-06-20 13:05:42
# Python Version: 3.10.14
# -----------------------------------
